# %% [markdown]
# Install necessary packages

# %%
# !pip install tensorflow numpy opencv-python Pillow ultralytics torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Requirement already satisfied: tensorflow in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: numpy in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: opencv-python in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: Pillow in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (10.4.0)
# Requirement already satisfied: ultralytics in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (8.3.40)
# Requirement already satisfied: torch in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (0.20.1+cu124)
# Requirement already satisfied: torchaudio in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (2.5.1+cu124)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.0.9)
# Requirement already satisfied: filelock in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: networkx in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\bagew\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %% [markdown]
# Import them

# %%
import tensorflow as tf
import torch
from ultralytics import YOLO
import numpy as np
import cv2
from PIL import Image
import glob
import os
import pickle
from collections import deque
import pandas as pd
from datetime import datetime

# %%
torch.cuda.is_available()

print("Is CUDA available:", torch.cuda.is_available())
print("PyTorch version:", torch.__version__)
# Out:
# Is CUDA available: True
# PyTorch version: 2.5.1+cu124

# %% [markdown]
# Create features/embeddings from the dataset

# %%
model_path = './20180402-114759.pb'
dataset_dir = './dataset'

# Load the FaceNet model
print("Loading FaceNet model...")
with tf.io.gfile.GFile(model_path, "rb") as f:
    graph_def = tf.compat.v1.GraphDef() 
    graph_def.ParseFromString(f.read())

with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name="")
print("Model loaded successfully.")

# Get input and output tensors
input_tensor = graph.get_tensor_by_name('input:0') 
output_tensor = graph.get_tensor_by_name('embeddings:0')

# Function to preprocess the image and generate embeddings
def generate_embedding(image_path):
    # Open the image and convert it to RGB format (3 channels)
    image = Image.open(image_path).convert('RGB').resize((160, 160))
    image = np.array(image) / 255.0 
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    with tf.compat.v1.Session(graph=graph) as sess:
        embedding = sess.run(output_tensor, feed_dict={
            input_tensor: image,
            graph.get_tensor_by_name('phase_train:0'): False
        })

    # Normalize the embedding
    normalized_embedding = embedding[0] / np.linalg.norm(embedding[0])
    return normalized_embedding

# Dictionary to store embeddings with labels
embeddings_dict = {}

# Process each image in the dataset directory
print("Starting embedding generation for each image...")
for image_path in glob.glob(os.path.join(dataset_dir, '*.png')):  #image format
    label = os.path.basename(image_path).split('.')[0]  # Get label from file name
    print(f"Processing image: {label}")
    embedding = generate_embedding(image_path)
    # print(embedding.shape[-1])
    embeddings_dict[label] = embedding
    print(f"Embedding generated for {label}: {embedding[:5]}...") 
# Save embeddings dictionary to a file for easy mapping
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings_dict, f)
print("All embeddings generated and saved successfully in 'embeddings.pkl'.")
# Out:
# Loading FaceNet model...
# WARNING:tensorflow:From C:\Users\bagew\AppData\Local\Temp\ipykernel_13532\93104209.py:7: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Model loaded successfully.
# Starting embedding generation for each image...
# Processing image: 101
# Embedding generated for 101: [   0.023957    0.015615   -0.033094   -0.012375   -0.038895]...
# Processing image: 102
# Embedding generated for 102: [   0.037405   -0.044949   -0.037431    0.010111   -0.031994]...
# Processing image: 103
# Embedding generated for 103: [   0.049462    0.050944   0.0021693   -0.065702   -0.087857]...
# Processing image: 104
# Embedding generated for 104: [  -0.028368    0.034861   -0.033094    0.024209   -0.052906]...
# Processing image: 106
# Embedding generated for 106: [  -0.029574    0.025538   -0.016259   -0.045912   -0.061736]...
# Processing image: 107
# Embedding generated for 107: [   0.036722   0.0024776   -0.012381   -0.053597    -0.10775]...
# Processing image: 108
# Embedding generated for 108: [ -0.0037316   -0.027756   -0.050823   -0.043343    0.046011]...
# Processing image: 112
# Embedding generated for 112: [   0.025297    0.005112  -0.0024553  -0.0035733   -0.045142]...
# Processing image: 113
# Embedding generated for 113: [   0.068052    0.045463   0.0061919    0.041181    0.019689]...
# Processing image: 114
# Embedding generated for 114: [   0.020463    0.057907   -0.036236    0.031866   -0.033496]...
# Processing image: 115
# Embedding generated for 115: [   0.028565    0.032199   -0.040249   -0.012178    0.048865]...
# Processing image: 117
# Embedding generated for 117: [ -0.0031084    0.059011  -0.0050771   0.0094284   -0.006843]...
# Processing image: 118
# Embedding generated for 118: [  -0.085583   -0.019902   -0.048705     -0.0197  -0.0015015]...
# Processing image: 121
# Embedding generated for 121: [   0.014938    0.012632   0.0041403  -0.0040845   -0.053732]...
# Processing image: 123
# Embedding generated for 123: [  0.0060992    0.010837    -0.03131    0.019028    0.030302]...
# Processing image: 124
# Embedding generated for 124: [   0.024923    0.004422   -0.046704   0.0013259   -0.049231]...
# Processing image: 126
# Embedding generated for 126: [ 0.00071517    0.031731   -0.016147  -0.0027817  -0.0025639]...
# Processing image: 127
# Embedding generated for 127: [  -0.029727    0.012857   -0.084776    0.073459   -0.032138]...
# Processing image: 129
# Embedding generated for 129: [  0.0075958    0.018564   -0.031394    0.018139   -0.060809]...
# Processing image: 130
# Embedding generated for 130: [   0.013646   -0.014148 -0.00031506    0.013594    0.054187]...
# Processing image: 131
# Embedding generated for 131: [   0.042607   -0.016571   -0.042003   0.0072758   -0.053748]...
# Processing image: 132
# Embedding generated for 132: [   0.020646  -0.0005797   -0.091834   -0.016903   -0.041525]...
# Processing image: 134
# Embedding generated for 134: [   0.012302   0.0083393   -0.073402   0.0041946   -0.039654]...
# Processing image: 135
# Embedding generated for 135: [  -0.014624   0.0073999   -0.037709    -0.02152   -0.033047]...
# Processing image: 136
# Embedding generated for 136: [  0.0087628   -0.011053  -0.0070502    0.023923   -0.007682]...
# Processing image: 137
# Embedding generated for 137: [   0.051684    0.022842  -0.0049765    0.040753   -0.062748]...
# Processing image: 138
# Embedding generated for 138: [ 0.00036716    0.028826   -0.017675    -0.05246  -0.0084904]...
# Processing image: 139
# Embedding generated for 139: [   0.027937   -0.024914   -0.038441    0.076366  -0.0026232]...
# Processing image: 141
# Embedding generated for 141: [   0.052357    0.050161    0.026935    0.020801   -0.045932]...
# Processing image: 143
# Embedding generated for 143: [  0.0097319  -0.0044064   -0.043243   -0.020954   0.0064857]...
# Processing image: 144
# Embedding generated for 144: [ -0.0097078   -0.022142   -0.067878   -0.032787   -0.022425]...
# Processing image: 147
# Embedding generated for 147: [  -0.015124    0.048379    0.038272  -0.0018451     -0.0456]...
# Processing image: 153
# Embedding generated for 153: [   0.031449   -0.035765   -0.038279  0.00010373    -0.03067]...
# Processing image: 157
# Embedding generated for 157: [  -0.029647  -0.0019432   -0.025493    0.053547    0.061166]...
# Processing image: 159
# Embedding generated for 159: [ -0.0074655   -0.027169   -0.097134    0.015027   -0.018077]...
# Processing image: 161
# Embedding generated for 161: [   0.013221   -0.011019   -0.033528   -0.016007    0.026844]...
# Processing image: 167
# Embedding generated for 167: [   -0.03064    0.013745   -0.037336    0.016856    0.027346]...
# Processing image: 172
# Embedding generated for 172: [   0.067813    0.014162    0.012664    0.044809   0.0026583]...
# All embeddings generated and saved successfully in 'embeddings.pkl'.

# %% [markdown]
# Test over static image recognition

# %% [markdown]
# Integrate Yolo for Dynamic detection with FaceNet

# %%
# FOR OVERWRITING

# Load FaceNet model
model_path = './20180402-114759.pb'

print("Loading FaceNet model...")
with tf.io.gfile.GFile(model_path, "rb") as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())

with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name="")

input_tensor = graph.get_tensor_by_name('input:0')
output_tensor = graph.get_tensor_by_name('embeddings:0')

# Set up device for GPU in PyTorch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load embeddings from the file
with open('embeddings.pkl', 'rb') as f:
    embeddings_dict = pickle.load(f)

# Initialize YOLO model and move it to GPU
yolo_model = YOLO('yolo11m.pt')
yolo_model = yolo_model.to(device)

# Set up TensorFlow session to use GPU
gpu_options = tf.compat.v1.GPUOptions(allow_growth=True)
sess = tf.compat.v1.Session(graph=graph, config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# Initialize buffers and logs
identity_buffer = deque(maxlen=10)
detection_logs = []
detection_count = {}

# Load or create the timetable DataFrame
try:
    attendance_df = pd.read_excel("attendance.xlsx", index_col=0)
except FileNotFoundError:
    columns = ["Sunday 1:30-20:00"]
    roll_numbers = [f"{i}" for i in range(101, 173)]
    attendance_df = pd.DataFrame(index=roll_numbers, columns=columns)


cap = cv2.VideoCapture(0)

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Convert frame to a PyTorch tensor and move it to the GPU
        frame_tensor = torch.from_numpy(frame).permute(2, 0, 1).float().to(device)

        # Run YOLO detection on the GPU
        results = yolo_model.predict(frame_tensor)
        current_frame_ids = []

        for result in results:
            boxes = result.boxes.xyxy.cpu().numpy()
            confidences = result.boxes.conf.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()

            for i in range(len(boxes)):
                x1, y1, x2, y2 = map(int, boxes[i])
                conf = confidences[i]
                cls = int(classes[i])

                if cls == 0 and conf > 0.5:
                    face_crop = frame[y1:y2, x1:x2]
                    face_image = Image.fromarray(cv2.cvtColor(face_crop, cv2.COLOR_BGR2RGB)).resize((160, 160))
                    face_array = np.array(face_image) / 255.0
                    face_array = np.expand_dims(face_array, axis=0)

                    with tf.device('/device:GPU:0'):
                        face_embedding = sess.run(output_tensor, feed_dict={
                            input_tensor: face_array,
                            graph.get_tensor_by_name('phase_train:0'): False
                        })[0]

                    min_dist = float("inf")
                    identity = "Unknown"

                    for name, stored_embedding in embeddings_dict.items():
                        dist = np.linalg.norm(stored_embedding - face_embedding)
                        if dist < min_dist:
                            min_dist = dist
                            identity = name

                    if min_dist < 0.975:
                        current_frame_ids.append(identity)
                        identity_buffer.append(identity)
                        stable_identity = str(max(set(identity_buffer), key=identity_buffer.count))


                        if stable_identity != "Unknown":
                            detection_count[stable_identity] = detection_count.get(stable_identity, 0) + 1

                            print("Count: ",detection_count[stable_identity])
                            if detection_count[stable_identity] > 20:
                                print("Insode if Count: ",detection_count[stable_identity])
                                current_time = datetime.now().strftime("%H:%M")
                                time_slots = {
                                    "10:15-12:15": ("10:15", "12:15"),
                                    "1:30-8:00": ("13:30", "20:00")
                                }

                                for slot, (start, end) in time_slots.items():
                                    if (start <= current_time) and (current_time <= end):
                                        print(f"Marking {stable_identity} Present")

                                        attendance_df.index = attendance_df.index.astype(str).str.strip().str.lower()
                                        stable_identity = stable_identity.strip().lower()

                                
                                        # Check and update attendance
                                        if stable_identity in attendance_df.index:
                                            attendance_df.loc[stable_identity, f"Sunday {slot}"] = 'P'
                                        else:
                                            print(f"Stable identity '{stable_identity}' not found in DataFrame index.")
                                        break

                        label = f"{stable_identity}"
                    else:
                        identity_buffer.append("Unknown")
                        label = "Unknown"

                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        cv2.imshow("Face Recognition", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

finally:
    cap.release()
    cv2.destroyAllWindows()
    sess.close()

    # Save updated attendance
    current_time = datetime.now().strftime("%H-%M")
    attendance_df.to_excel(f"attendance.xlsx")
    print("Attendance saved to attendance.xlsx")
# Out:
# Loading FaceNet model...
# WARNING:tensorflow:From C:\Users\bagew\AppData\Local\Temp\ipykernel_2636\4252981536.py:8: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# Using device: cuda
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 68.9ms
# Speed: 0.0ms preprocess, 68.9ms inference, 82.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 couch, 1 bed, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 couch, 1 bed, 24.2ms
# Speed: 0.0ms preprocess, 24.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 24.7ms
# Speed: 0.0ms preprocess, 24.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 23.3ms
# Speed: 0.0ms preprocess, 23.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.1ms
# Speed: 0.0ms preprocess, 25.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Count:  1
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  2
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  3
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Count:  4
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.8ms
# Speed: 0.0ms preprocess, 21.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  5
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 16.5ms
# Speed: 0.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  6
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  7
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  8
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  9
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  10
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  11
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  12
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 18.9ms
# Speed: 0.0ms preprocess, 18.9ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
# Count:  13
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 11.8ms postprocess per image at shape (1, 3, 480, 640)
# Count:  14
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  15
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  16
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Count:  17
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 12.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  18
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  19
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 11.3ms
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  20
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  21
# Insode if Count:  21
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  22
# Insode if Count:  22
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  23
# Insode if Count:  23
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.5ms
# Speed: 0.0ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  24
# Insode if Count:  24
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  25
# Insode if Count:  25
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.8ms
# Speed: 0.0ms preprocess, 22.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 13.3ms
# Speed: 0.0ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 29.7ms
# Speed: 0.0ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  26
# Insode if Count:  26
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  27
# Insode if Count:  27
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  28
# Insode if Count:  28
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.0ms
# Speed: 0.0ms preprocess, 27.0ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Count:  29
# Insode if Count:  29
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  30
# Insode if Count:  30
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.5ms
# Speed: 0.0ms preprocess, 26.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  31
# Insode if Count:  31
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  32
# Insode if Count:  32
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Count:  33
# Insode if Count:  33
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Count:  34
# Insode if Count:  34
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.1ms
# Speed: 0.0ms preprocess, 25.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Count:  35
# Insode if Count:  35
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.7ms
# Speed: 0.0ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  36
# Insode if Count:  36
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 28.0ms
# Speed: 0.0ms preprocess, 28.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  37
# Insode if Count:  37
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Count:  38
# Insode if Count:  38
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  39
# Insode if Count:  39
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.4ms
# Speed: 0.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  40
# Insode if Count:  40
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Count:  41
# Insode if Count:  41
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.2ms
# Speed: 0.0ms preprocess, 26.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  42
# Insode if Count:  42
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  43
# Insode if Count:  43
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.4ms
# Speed: 0.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  44
# Insode if Count:  44
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  45
# Insode if Count:  45
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Count:  46
# Insode if Count:  46
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.6ms
# Speed: 0.0ms preprocess, 27.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Count:  47
# Insode if Count:  47
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  48
# Insode if Count:  48
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 17.6ms
# Speed: 0.0ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  49
# Insode if Count:  49
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.2ms
# Speed: 0.0ms preprocess, 22.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  50
# Insode if Count:  50
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.1ms
# Speed: 0.0ms preprocess, 23.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Count:  51
# Insode if Count:  51
# Marking 130 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 clock, 26.2ms
# Speed: 0.0ms preprocess, 26.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 18.7ms
# Speed: 0.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 29.1ms
# Speed: 0.0ms preprocess, 29.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.3ms
# Speed: 0.0ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.9ms
# Speed: 0.0ms preprocess, 27.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 13.9ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.7ms
# Speed: 0.0ms preprocess, 26.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.0ms
# Speed: 0.0ms preprocess, 26.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 22.8ms
# Speed: 0.0ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 28.5ms
# Speed: 0.0ms preprocess, 28.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.9ms
# Speed: 0.0ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.8ms
# Speed: 0.0ms preprocess, 27.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.0ms
# Speed: 0.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.5ms
# Speed: 0.0ms preprocess, 24.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.7ms
# Speed: 0.0ms preprocess, 24.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.0ms
# Speed: 0.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.1ms
# Speed: 0.0ms preprocess, 26.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
# 0: 480x640 2 persons, 1 chair, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  20
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 2 persons, 28.4ms
# Speed: 0.0ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  21
# Insode if Count:  21
# Marking 131 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 3 persons, 29.2ms
# Speed: 0.0ms preprocess, 29.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Count:  22
# Insode if Count:  22
# Marking 131 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 2 persons, 1 bed, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Count:  23
# Insode if Count:  23
# Marking 131 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 2 persons, 1 bed, 28.7ms
# Speed: 0.0ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Count:  24
# Insode if Count:  24
# Marking 131 Present
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 2 persons, 25.7ms
# Speed: 0.0ms preprocess, 25.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 2 persons, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 remote, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.6ms
# Speed: 0.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 25.2ms
# Speed: 0.0ms preprocess, 25.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.6ms
# Speed: 0.0ms preprocess, 23.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 11.8ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.2ms
# Speed: 0.0ms preprocess, 22.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.8ms
# Speed: 0.0ms preprocess, 24.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 27.5ms
# Speed: 0.0ms preprocess, 27.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 bed, 1 remote, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 remote, 29.3ms
# Speed: 0.0ms preprocess, 29.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.6ms
# Speed: 0.0ms preprocess, 24.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 30.0ms
# Speed: 0.0ms preprocess, 30.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 22.9ms
# Speed: 0.0ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 remote, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 1 remote, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 23.3ms
# Speed: 0.0ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.4ms
# Speed: 0.0ms preprocess, 26.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 26.6ms
# Speed: 0.0ms preprocess, 26.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 25.1ms
# Speed: 0.0ms preprocess, 25.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# WARNING  torch.Tensor inputs should be BCHW i.e. shape(1, 3, 640, 640) divisible by stride 32. Input shape(3, 480, 640) is incompatible.
# WARNING  torch.Tensor inputs should be normalized 0.0-1.0 but max value is 255.0. Dividing input by 255.
# 0: 480x640 1 person, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Attendance saved to attendance.xlsx
